# %%
# ====================================================
# 模型训练
# ====================================================

import sys
import os
import math
import time
import random
import shutil
from pathlib import Path
import scipy as sp
import numpy as np
import pandas as pd
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
import cv2
from PIL import Image
import natsort  #排序
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.optim import Adam, Adamax
import torchvision.models as models
from torch.nn.parameter import Parameter
from torch.utils.data import DataLoader, Dataset
from torch.optim.lr_scheduler import ReduceLROnPlateau
from albumentations import (Compose, Normalize, Resize, RandomResizedCrop, HorizontalFlip, VerticalFlip, ShiftScaleRotate,RandomGridShuffle, Transpose,Rotate)
from albumentations.pytorch import ToTensorV2
import timm
import warnings 
warnings.filterwarnings('ignore')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

# %%
# ====================================================
# 目录设置
# ====================================================

import os

OUTPUT_DIR = './'
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)

TRAIN_PATH = './images_output_cnn/'
data = pd.read_csv('./train.csv')

# %%
# ====================================================
# 全局参数
# ====================================================

class CFG:
    print_freq=100
    num_workers = 12 #进程数,win系统必须为设置为0
    model_name = 'mobilenetv3_large_100'
    size = 512  #图像大小512*512
    epochs = 30  #训练次数
    factor = 0.4 #学习率每次降低多少
    patience = 3 #容忍网路的性能不提升的次数，高于这个次数就降低学习率
    eps = 1e-6 #lr的最小衰减
    lr = 1e-3
    min_lr = 1e-6
    batch_size = 64
    weight_decay = 1e-6
    gradient_accumulation_steps = 1#累计梯度来解决本地显存不足问题
    max_grad_norm = 10 #梯度的最大范数
    seed = 666 #全局种子
    target_size = 7  #n种类型进行划分
    target_col = 'label'
    n_fold = 5
    criterion = 'LabelSmoothingLoss'#标签平滑
    criterion_params = {'CrossEntropyLoss': {'weight':None,'size_average':None,
                                             'ignore_index':-100,'reduce':None,
                                             'reduction':'mean'},
                        'LabelSmoothingLoss': {'classes':7, 'smoothing':0.05, 'dim':-1},
                        'FocalCosineLoss': {'alpha':1, 'gamma':2 , 'xent':0.1}}
    #trn_fold = [1,2,3,4,5]
    
    
#全局种子
def seed_torch(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)#神经网络中，参数
    torch.cuda.manual_seed(seed)#GPU设置随机种子
    torch.backends.cudnn.deterministic = True #cuda的随机数种子,默认算法

seed_torch(seed=CFG.seed)

# %%
# ====================================================
# 标签平滑
# ====================================================
class LabelSmoothingLoss(nn.Module): 
    def __init__(self, classes=7, smoothing=0.0, dim=-1): 
        super(LabelSmoothingLoss, self).__init__() 
        self.confidence = 1.0 - smoothing 
        self.smoothing = smoothing 
        self.classes = classes 
        self.dim = dim 
    def forward(self, input, target): 
        pred = input.log_softmax(dim=self.dim) 
        with torch.no_grad():
            true_dist = torch.zeros_like(pred) 
            true_dist.fill_(self.smoothing / (self.classes - 1)) 
            true_dist.scatter_(1, target.data.unsqueeze(1), self.confidence) 
        return torch.mean(torch.sum(-true_dist * pred, dim=self.dim))

# %%
criterion=LabelSmoothingLoss(**CFG.criterion_params[CFG.criterion]).to(device)#标签平滑

# %%
class AverageMeter(object):
    """#计算并存储平均值和当前值"""
    def __init__(self):
        self.reset()

    def reset(self):
        self.val = 0
        self.avg = 0
        self.sum = 0
        self.count = 0

    def update(self, val, n=1):
        self.val = val
        self.sum += val * n
        self.count += n
        self.avg = self.sum / self.count
        
        
def timeSince(since, percent):#时间间隔
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s#剩余时间
    return '%s (remain %s)' % (asMinutes(s), asMinutes(rs))
def asMinutes(s):
    m = math.floor(s / 60)  #分,返回数字的下舍整数
    s -= m * 60             #已过s秒
    return '%dm %ds' % (m, s)

def get_score(y_true, y_pred):
    return accuracy_score(y_true, y_pred)

# %%
# ====================================================
# 数据集
# ====================================================

class TrainDataset(Dataset):
    def __init__(self, df, transform=None):
        self.df = df
        self.file_names = df['image_id'].values
        self.labels = df['label'].values
        self.transform = transform
        
    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        file_name = self.file_names[idx]
        file_path = f'{TRAIN_PATH}/{file_name}'
        image = cv2.imread(file_path)
        image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
        if self.transform:
            augmented = self.transform(image=image)
            image = augmented['image']
        label = torch.tensor(self.labels[idx]).long()
        return image, label

# %%
###########################################################
#图像增强
##########################################################
def get_transforms(*, data):
    
    if data == 'train':
        return Compose([
            Transpose(p=0.5),    #转置,将图像行和列互换
            HorizontalFlip(p=0.5),#垂直翻转
            VerticalFlip(p=0.5),#水平翻转
            RandomGridShuffle(grid=(3,3), always_apply=False, p=0.5),#网格洗牌
            Rotate(limit=90, interpolation=1, border_mode=4, value=None, mask_value=None, always_apply=False, p=0.5),
            #随机旋转图片
            Resize(CFG.size, CFG.size),
            #归一化,ImageNet的均值和标准差。
            Normalize(
                mean=[0.485, 0.456, 0.406],
                std=[0.229, 0.224, 0.225],
            ),
            ToTensorV2(),
        ])
    
    elif data == 'valid':
       return Compose([
           Resize(CFG.size, CFG.size),
           Normalize(
               mean=[0.485, 0.456, 0.406],
               std=[0.229, 0.224, 0.225],
           ),
           ToTensorV2(),
       ])

# %%
# ====================================================
# 模型初始化
# ====================================================

class load_init_model(nn.Module):
    def __init__(self, model_name=CFG.model_name, pretrained=False):
        super().__init__()
        self.model = timm.create_model(model_name, pretrained=pretrained)#加载模型
        net = Net()
        self.model.classifier=net

    def forward(self, x):
        x = self.model(x)
        return x

# %%
###############################
#修改最后一层
################################
class Net(nn.Module):
    def __init__(self):
        super(Net,self).__init__()
        #开始构建线性层
        self.fc1=nn.Linear(1280,400)
        self.fc2=nn.Linear(400,100)
        self.fc3=nn.Linear(100,7)
    def forward(self,x):
        x=x.view(-1,1280)#通过view函数将张量x变成 一维向量
        x=F.relu(self.fc1(x))
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return  x

# %%
##################################################
#网络训练
##################################################
def train_fn(train_loader, model, optimizer, epoch, scheduler, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    start = time.time()
    global_step = 0
    
    model.train()
    for step, (images, labels) in enumerate(train_loader):
        images = images.to(device)  #数据传到相应设备计算
        labels = labels.to(device)
        batch_size = labels.size(0)
        y_preds = model(images)
        
        loss = criterion(input=y_preds, target=labels)#标签平滑        
        losses.update(loss.item(), batch_size)
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        else:
            loss.backward()#反向传播计算
        grad_norm = torch.nn.utils.clip_grad_norm_(model.parameters(), CFG.max_grad_norm)#计算全局梯度范数
        if (step + 1) % CFG.gradient_accumulation_steps == 0:
            optimizer.step()
            optimizer.zero_grad()
            global_step += 1
        end = time.time()
        batch_time.update(time.time() - end)
        
        if step % CFG.print_freq == 0 or step == (len(train_loader)-1):
            print('Epoch: [{0}][{1}/{2}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  'Grad: {grad_norm:.4f}  '
                  .format(
                   epoch+1, step, len(train_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(train_loader)),
                   grad_norm=grad_norm,
                   ))
    return losses.avg

# %%
##################################################
#valid层
##################################################

def valid_fn(valid_loader, model, device):
    batch_time = AverageMeter()
    data_time = AverageMeter()
    losses = AverageMeter()
    scores = AverageMeter()
    model.eval()
    preds = []
    start = end = time.time()
    for step, (images, labels) in enumerate(valid_loader):
        data_time.update(time.time() - end)
        images = images.to(device)
        labels = labels.to(device)
        batch_size = labels.size(0)
        with torch.no_grad():
            y_preds = model(images)
        loss = criterion(input=y_preds, target=labels)#标签平滑
        losses.update(loss.item(), batch_size)
        preds.append(y_preds.softmax(1).to('cpu').numpy())
        if CFG.gradient_accumulation_steps > 1:
            loss = loss / CFG.gradient_accumulation_steps
        end = time.time()
        batch_time.update(time.time() - end)
        
        if step % CFG.print_freq == 0 or step == (len(valid_loader)-1):
            print('EVAL: [{0}/{1}] '
                  'Data {data_time.val:.3f} ({data_time.avg:.3f}) '
                  'Elapsed {remain:s} '
                  'Loss: {loss.val:.4f}({loss.avg:.4f}) '
                  .format(
                   step, len(valid_loader), batch_time=batch_time,
                   data_time=data_time, loss=losses,
                   remain=timeSince(start, float(step+1)/len(valid_loader)),
                   ))
    predictions = np.concatenate(preds)
    return losses.avg, predictions

# %%
######################################################
#训练主循环
######################################################
def train_loop(data, fold):
    trnin_index = data[data['fold'] != fold].index
    valid_index = data[data['fold'] == fold].index
    
    train_folds = data.loc[trnin_index].reset_index(drop=True)
    valid_folds = data.loc[valid_index].reset_index(drop=True)
    
    train_dataset = TrainDataset(train_folds, transform=get_transforms(data='train'))
    valid_dataset = TrainDataset(valid_folds, transform=get_transforms(data='valid'))
    
    train_loader = DataLoader(train_dataset, batch_size=CFG.batch_size, 
                              shuffle=True, num_workers=CFG.num_workers, pin_memory=True, drop_last=True)
    valid_loader = DataLoader(valid_dataset, batch_size=CFG.batch_size, 
                              shuffle=False, num_workers=CFG.num_workers, pin_memory=True, drop_last=False)
    
    model = load_init_model(CFG.model_name, pretrained=True)
    model.to(device)
    optimizer = Adam(model.parameters(), lr=CFG.lr, weight_decay=CFG.weight_decay, amsgrad=False)
    scheduler = ReduceLROnPlateau(optimizer, mode='min', factor=CFG.factor, patience=CFG.patience,
                                  verbose=True, eps=CFG.eps)
  

    
    best_score = 0.
    best_loss = np.inf
    
    for epoch in range(CFG.epochs):
        start_time = time.time()
        avg_loss = train_fn(train_loader, model, optimizer, epoch, scheduler, device)
        
        avg_val_loss, preds = valid_fn(valid_loader, model, device)
        valid_labels = valid_folds[CFG.target_col].values
        scheduler.step(avg_val_loss)
        scheduler.step(avg_val_loss)
        score = get_score(valid_labels, preds.argmax(1))
        print('accuracy_score:',score)
        
        
        if score > best_score:
            best_score = score
            torch.save(model, OUTPUT_DIR+f'{CFG.model_name}_fold{fold}_best.pth')
            print('save the best model')
            print('save the best model')
            print('best_score:',best_score)
            preds = preds
            
    valid_folds[[str(c) for c in range(7)]] = preds
    valid_folds['preds'] = preds.argmax(1)

    return valid_folds

# %%
def get_result(result_df):
    preds = result_df['preds'].values
    labels = result_df[CFG.target_col].values
    score = get_score(labels, preds)

# %%
def main():
    oof_df = pd.DataFrame()
    for fold in range(CFG.n_fold):
        
        print("======= {0} fold=========".format(fold+1))
        _oof_df = train_loop(data, fold)
        oof_df = pd.concat([oof_df, _oof_df])
        get_result(_oof_df)
    get_result(oof_df)
    oof_df.to_csv(OUTPUT_DIR+'oof_df.csv', index=False)

# %%
if __name__ == '__main__':
    main()
# Out:
# ======= 1 fold=========
# Epoch: [1][0/33] Data 0.000 (0.000) Elapsed 0m 14s (remain 7m 35s) Loss: 1.9468(1.9468) Grad: 0.3025
# Epoch: [1][32/33] Data 0.000 (0.000) Elapsed 0m 23s (remain 0m 0s) Loss: 1.3134(1.3298) Grad: 2.0030
# EVAL: [0/9] Data 2.955 (2.955) Elapsed 0m 3s (remain 0m 24s) Loss: 1.0600(1.0600)
# EVAL: [8/9] Data 0.000 (0.329) Elapsed 0m 4s (remain 0m 0s) Loss: 1.5913(1.2408)
# accuracy_score: 0.5942549371633752
# save the best model
# save the best model
# best_score: 0.5942549371633752
# Epoch: [2][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 58s) Loss: 0.9777(0.9777) Grad: 1.0425
# Epoch: [2][32/33] Data 0.000 (0.000) Elapsed 0m 17s (remain 0m 0s) Loss: 1.0702(1.0297) Grad: 1.7883
# EVAL: [0/9] Data 2.747 (2.747) Elapsed 0m 2s (remain 0m 22s) Loss: 0.8580(0.8580)
# EVAL: [8/9] Data 0.000 (0.318) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1833(1.0344)
# accuracy_score: 0.6642728904847397
# save the best model
# save the best model
# best_score: 0.6642728904847397
# Epoch: [3][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 40s) Loss: 0.9198(0.9198) Grad: 2.3295
# Epoch: [3][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9306(0.9356) Grad: 1.9237
# EVAL: [0/9] Data 2.949 (2.949) Elapsed 0m 3s (remain 0m 24s) Loss: 0.8380(0.8380)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 1.3615(1.0248)
# accuracy_score: 0.6678635547576302
# save the best model
# save the best model
# best_score: 0.6678635547576302
# Epoch: [4][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 28s) Loss: 0.7635(0.7635) Grad: 1.3801
# Epoch: [4][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.0882(0.8588) Grad: 2.2297
# EVAL: [0/9] Data 2.752 (2.752) Elapsed 0m 2s (remain 0m 22s) Loss: 0.9551(0.9551)
# EVAL: [8/9] Data 0.000 (0.333) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9799(1.0124)
# accuracy_score: 0.6337522441651705
# Epoch: [5][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 15s) Loss: 0.9242(0.9242) Grad: 1.7089
# Epoch: [5][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7994(0.8140) Grad: 1.2131
# EVAL: [0/9] Data 2.852 (2.852) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5935(0.5935)
# EVAL: [8/9] Data 0.000 (0.323) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1450(0.9478)
# accuracy_score: 0.7414721723518851
# save the best model
# save the best model
# best_score: 0.7414721723518851
# Epoch: [6][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 2m 56s) Loss: 0.7990(0.7990) Grad: 1.2887
# Epoch: [6][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7432(0.7433) Grad: 1.3713
# EVAL: [0/9] Data 3.130 (3.130) Elapsed 0m 3s (remain 0m 25s) Loss: 0.7825(0.7825)
# EVAL: [8/9] Data 0.000 (0.348) Elapsed 0m 3s (remain 0m 0s) Loss: 1.6244(0.9467)
# accuracy_score: 0.6983842010771992
# Epoch: [7][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 58s) Loss: 0.6823(0.6823) Grad: 1.4466
# Epoch: [7][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7191(0.7255) Grad: 1.6728
# EVAL: [0/9] Data 2.981 (2.981) Elapsed 0m 3s (remain 0m 24s) Loss: 0.5822(0.5822)
# EVAL: [8/9] Data 0.000 (0.331) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9588(0.8387)
# accuracy_score: 0.7719928186714542
# save the best model
# save the best model
# best_score: 0.7719928186714542
# Epoch: [8][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 27s) Loss: 0.5731(0.5731) Grad: 1.1012
# Epoch: [8][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6852(0.6731) Grad: 1.4638
# EVAL: [0/9] Data 2.728 (2.728) Elapsed 0m 2s (remain 0m 22s) Loss: 0.9292(0.9292)
# EVAL: [8/9] Data 0.000 (0.315) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7787(0.8306)
# accuracy_score: 0.7594254937163375
# Epoch: [9][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.6872(0.6872) Grad: 1.5830
# Epoch: [9][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5473(0.6032) Grad: 1.3015
# EVAL: [0/9] Data 3.000 (3.000) Elapsed 0m 3s (remain 0m 24s) Loss: 0.6039(0.6039)
# EVAL: [8/9] Data 0.000 (0.333) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7039(0.7007)
# accuracy_score: 0.8043087971274686
# save the best model
# save the best model
# best_score: 0.8043087971274686
# Epoch: [10][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 43s) Loss: 0.4883(0.4883) Grad: 0.9372
# Epoch: [10][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4914(0.5949) Grad: 1.2263
# EVAL: [0/9] Data 2.612 (2.612) Elapsed 0m 2s (remain 0m 21s) Loss: 0.5528(0.5528)
# EVAL: [8/9] Data 0.000 (0.332) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8870(0.8199)
# accuracy_score: 0.7863554757630161
# Epoch: [11][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 38s) Loss: 0.6415(0.6415) Grad: 1.5470
# Epoch: [11][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6125(0.6012) Grad: 1.3411
# EVAL: [0/9] Data 3.065 (3.065) Elapsed 0m 3s (remain 0m 25s) Loss: 0.8910(0.8910)
# EVAL: [8/9] Data 0.000 (0.341) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0500(0.9237)
# Epoch    21: reducing learning rate of group 0 to 4.0000e-04.
# accuracy_score: 0.7360861759425493
# Epoch: [12][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 43s) Loss: 0.6978(0.6978) Grad: 1.7411
# Epoch: [12][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5756(0.5205) Grad: 1.5509
# EVAL: [0/9] Data 2.695 (2.695) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5816(0.5816)
# EVAL: [8/9] Data 0.000 (0.312) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6616(0.6102)
# accuracy_score: 0.8312387791741472
# save the best model
# save the best model
# best_score: 0.8312387791741472
# Epoch: [13][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 32s) Loss: 0.3992(0.3992) Grad: 0.9131
# Epoch: [13][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4902(0.4534) Grad: 0.9521
# EVAL: [0/9] Data 2.687 (2.687) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5400(0.5400)
# EVAL: [8/9] Data 0.000 (0.325) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6741(0.6137)
# accuracy_score: 0.8330341113105925
# save the best model
# save the best model
# best_score: 0.8330341113105925
# Epoch: [14][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 10s) Loss: 0.4412(0.4412) Grad: 1.2158
# Epoch: [14][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4375(0.4181) Grad: 1.0592
# EVAL: [0/9] Data 3.032 (3.032) Elapsed 0m 3s (remain 0m 24s) Loss: 0.5112(0.5112)
# EVAL: [8/9] Data 0.000 (0.337) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6249(0.5998)
# accuracy_score: 0.8509874326750448
# save the best model
# save the best model
# best_score: 0.8509874326750448
# Epoch: [15][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 42s) Loss: 0.3800(0.3800) Grad: 0.8294
# Epoch: [15][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3872(0.4011) Grad: 0.8094
# EVAL: [0/9] Data 2.709 (2.709) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4683(0.4683)
# EVAL: [8/9] Data 0.000 (0.314) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5635(0.5623)
# accuracy_score: 0.881508078994614
# save the best model
# save the best model
# best_score: 0.881508078994614
# Epoch: [16][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 15s) Loss: 0.3445(0.3445) Grad: 0.5728
# Epoch: [16][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3689(0.4083) Grad: 0.9192
# EVAL: [0/9] Data 2.869 (2.869) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5673(0.5673)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6587(0.6053)
# accuracy_score: 0.8563734290843806
# Epoch: [17][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 49s) Loss: 0.5172(0.5172) Grad: 2.1714
# Epoch: [17][32/33] Data 0.000 (0.000) Elapsed 0m 17s (remain 0m 0s) Loss: 0.4040(0.4097) Grad: 1.2219
# EVAL: [0/9] Data 2.677 (2.677) Elapsed 0m 2s (remain 0m 21s) Loss: 0.4494(0.4494)
# EVAL: [8/9] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5669(0.6273)
# Epoch    33: reducing learning rate of group 0 to 1.6000e-04.
# accuracy_score: 0.8473967684021544
# Epoch: [18][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 35s) Loss: 0.3300(0.3300) Grad: 0.4346
# Epoch: [18][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3308(0.3695) Grad: 0.4128
# EVAL: [0/9] Data 2.637 (2.637) Elapsed 0m 2s (remain 0m 21s) Loss: 0.4657(0.4657)
# EVAL: [8/9] Data 0.000 (0.319) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5275(0.5729)
# accuracy_score: 0.874326750448833
# Epoch: [19][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 1s) Loss: 0.3272(0.3272) Grad: 0.3030
# Epoch: [19][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4159(0.3533) Grad: 1.4295
# EVAL: [0/9] Data 2.798 (2.798) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4451(0.4451)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5046(0.5682)
# Epoch    37: reducing learning rate of group 0 to 6.4000e-05.
# accuracy_score: 0.8850987432675045
# save the best model
# save the best model
# best_score: 0.8850987432675045
# Epoch: [20][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 45s) Loss: 0.4075(0.4075) Grad: 1.4764
# Epoch: [20][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3579(0.3515) Grad: 1.0951
# EVAL: [0/9] Data 3.131 (3.131) Elapsed 0m 3s (remain 0m 25s) Loss: 0.4454(0.4454)
# EVAL: [8/9] Data 0.000 (0.348) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4865(0.5576)
# accuracy_score: 0.8886894075403949
# save the best model
# save the best model
# best_score: 0.8886894075403949
# Epoch: [21][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 59s) Loss: 0.3715(0.3715) Grad: 0.8949
# Epoch: [21][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3638(0.3480) Grad: 0.8047
# EVAL: [0/9] Data 3.069 (3.069) Elapsed 0m 3s (remain 0m 25s) Loss: 0.4385(0.4385)
# EVAL: [8/9] Data 0.000 (0.341) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4984(0.5605)
# accuracy_score: 0.8886894075403949
# Epoch: [22][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 21s) Loss: 0.3899(0.3899) Grad: 1.3170
# Epoch: [22][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3085(0.3475) Grad: 0.3110
# EVAL: [0/9] Data 2.871 (2.871) Elapsed 0m 2s (remain 0m 23s) Loss: 0.4403(0.4403)
# EVAL: [8/9] Data 0.000 (0.331) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4814(0.5455)
# accuracy_score: 0.8850987432675045
# Epoch: [23][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 56s) Loss: 0.3842(0.3842) Grad: 0.7854
# Epoch: [23][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3179(0.3433) Grad: 0.5555
# EVAL: [0/9] Data 2.610 (2.610) Elapsed 0m 2s (remain 0m 21s) Loss: 0.4394(0.4394)
# EVAL: [8/9] Data 0.000 (0.308) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4750(0.5468)
# accuracy_score: 0.8886894075403949
# Epoch: [24][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 10s) Loss: 0.3670(0.3670) Grad: 0.9154
# Epoch: [24][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3494(0.3461) Grad: 0.8333
# EVAL: [0/9] Data 3.113 (3.113) Elapsed 0m 3s (remain 0m 25s) Loss: 0.4341(0.4341)
# EVAL: [8/9] Data 0.000 (0.346) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4645(0.5509)
# Epoch    47: reducing learning rate of group 0 to 2.5600e-05.
# accuracy_score: 0.8886894075403949
# Epoch: [25][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 54s) Loss: 0.3140(0.3140) Grad: 0.4422
# Epoch: [25][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3069(0.3379) Grad: 0.2281
# EVAL: [0/9] Data 2.842 (2.842) Elapsed 0m 2s (remain 0m 23s) Loss: 0.4479(0.4479)
# EVAL: [8/9] Data 0.000 (0.336) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4715(0.5478)
# accuracy_score: 0.8904847396768402
# save the best model
# save the best model
# best_score: 0.8904847396768402
# Epoch: [26][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 15s) Loss: 0.3141(0.3141) Grad: 0.3893
# Epoch: [26][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3274(0.3364) Grad: 0.4809
# EVAL: [0/9] Data 2.940 (2.940) Elapsed 0m 3s (remain 0m 24s) Loss: 0.4513(0.4513)
# EVAL: [8/9] Data 0.000 (0.327) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4784(0.5507)
# Epoch    51: reducing learning rate of group 0 to 1.0240e-05.
# accuracy_score: 0.8922800718132855
# save the best model
# save the best model
# best_score: 0.8922800718132855
# Epoch: [27][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 44s) Loss: 0.3092(0.3092) Grad: 0.3426
# Epoch: [27][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3347(0.3388) Grad: 0.4672
# EVAL: [0/9] Data 2.927 (2.927) Elapsed 0m 2s (remain 0m 23s) Loss: 0.4507(0.4507)
# EVAL: [8/9] Data 0.000 (0.331) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4714(0.5516)
# accuracy_score: 0.8922800718132855
# Epoch: [28][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.3327(0.3327) Grad: 0.7172
# Epoch: [28][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3589(0.3335) Grad: 1.3138
# EVAL: [0/9] Data 2.795 (2.795) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4267(0.4267)
# EVAL: [8/9] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4728(0.5419)
# accuracy_score: 0.8994614003590664
# save the best model
# save the best model
# best_score: 0.8994614003590664
# Epoch: [29][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 26s) Loss: 0.3204(0.3204) Grad: 0.5086
# Epoch: [29][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3494(0.3345) Grad: 0.9881
# EVAL: [0/9] Data 2.687 (2.687) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4606(0.4606)
# EVAL: [8/9] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4749(0.5492)
# accuracy_score: 0.8850987432675045
# Epoch: [30][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 36s) Loss: 0.3332(0.3332) Grad: 0.6704
# Epoch: [30][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3172(0.3341) Grad: 0.4448
# EVAL: [0/9] Data 2.877 (2.877) Elapsed 0m 2s (remain 0m 23s) Loss: 0.4479(0.4479)
# EVAL: [8/9] Data 0.000 (0.326) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4693(0.5509)
# Epoch    59: reducing learning rate of group 0 to 4.0960e-06.
# accuracy_score: 0.8868940754039497
# ======= 2 fold=========
# Epoch: [1][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 13s) Loss: 1.9379(1.9379) Grad: 0.4428
# Epoch: [1][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.1403(1.3601) Grad: 1.5972
# EVAL: [0/9] Data 2.581 (2.581) Elapsed 0m 2s (remain 0m 21s) Loss: 0.7664(0.7664)
# EVAL: [8/9] Data 0.000 (0.305) Elapsed 0m 3s (remain 0m 0s) Loss: 1.2109(1.0936)
# accuracy_score: 0.6605839416058394
# save the best model
# save the best model
# best_score: 0.6605839416058394
# Epoch: [2][0/33] Data 0.000 (0.000) Elapsed 0m 9s (remain 4m 50s) Loss: 1.0240(1.0240) Grad: 1.6729
# Epoch: [2][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.0767(1.0618) Grad: 1.9337
# EVAL: [0/9] Data 2.833 (2.833) Elapsed 0m 2s (remain 0m 23s) Loss: 0.7966(0.7966)
# EVAL: [8/9] Data 0.000 (0.336) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9509(1.0554)
# accuracy_score: 0.6259124087591241
# Epoch: [3][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 4s) Loss: 1.0443(1.0443) Grad: 1.5192
# Epoch: [3][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8593(0.9781) Grad: 1.4480
# EVAL: [0/9] Data 2.791 (2.791) Elapsed 0m 2s (remain 0m 22s) Loss: 0.9117(0.9117)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9442(0.9826)
# accuracy_score: 0.6788321167883211
# save the best model
# save the best model
# best_score: 0.6788321167883211
# Epoch: [4][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 8s) Loss: 0.8076(0.8076) Grad: 1.3942
# Epoch: [4][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9907(0.8771) Grad: 1.7684
# EVAL: [0/9] Data 2.965 (2.965) Elapsed 0m 3s (remain 0m 24s) Loss: 0.6483(0.6483)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8643(0.9175)
# accuracy_score: 0.7043795620437956
# save the best model
# save the best model
# best_score: 0.7043795620437956
# Epoch: [5][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 21s) Loss: 0.7480(0.7480) Grad: 1.1582
# Epoch: [5][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7943(0.8097) Grad: 1.1535
# EVAL: [0/9] Data 2.728 (2.728) Elapsed 0m 2s (remain 0m 22s) Loss: 0.7358(0.7358)
# EVAL: [8/9] Data 0.000 (0.308) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9610(0.9307)
# accuracy_score: 0.708029197080292
# save the best model
# save the best model
# best_score: 0.708029197080292
# Epoch: [6][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 20s) Loss: 0.7652(0.7652) Grad: 1.4512
# Epoch: [6][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6947(0.7883) Grad: 1.5057
# EVAL: [0/9] Data 2.697 (2.697) Elapsed 0m 2s (remain 0m 22s) Loss: 0.6019(0.6019)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7369(0.8812)
# accuracy_score: 0.7445255474452555
# save the best model
# save the best model
# best_score: 0.7445255474452555
# Epoch: [7][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 25s) Loss: 0.6045(0.6045) Grad: 1.1786
# Epoch: [7][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6624(0.7265) Grad: 2.2386
# EVAL: [0/9] Data 2.970 (2.970) Elapsed 0m 3s (remain 0m 24s) Loss: 0.7091(0.7091)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7580(0.7975)
# accuracy_score: 0.7901459854014599
# save the best model
# save the best model
# best_score: 0.7901459854014599
# Epoch: [8][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 2s) Loss: 0.6738(0.6738) Grad: 1.5124
# Epoch: [8][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6522(0.7036) Grad: 1.6210
# EVAL: [0/9] Data 2.929 (2.929) Elapsed 0m 3s (remain 0m 24s) Loss: 0.7440(0.7440)
# EVAL: [8/9] Data 0.000 (0.339) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1325(0.8328)
# accuracy_score: 0.7664233576642335
# Epoch: [9][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 53s) Loss: 0.5906(0.5906) Grad: 1.6600
# Epoch: [9][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6489(0.6478) Grad: 1.8855
# EVAL: [0/9] Data 2.723 (2.723) Elapsed 0m 2s (remain 0m 22s) Loss: 0.6939(0.6939)
# EVAL: [8/9] Data 0.000 (0.316) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6289(0.7596)
# accuracy_score: 0.7773722627737226
# Epoch: [10][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 38s) Loss: 0.6118(0.6118) Grad: 1.5707
# Epoch: [10][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5925(0.6283) Grad: 1.5611
# EVAL: [0/9] Data 2.870 (2.870) Elapsed 0m 2s (remain 0m 23s) Loss: 0.6366(0.6366)
# EVAL: [8/9] Data 0.000 (0.353) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7529(0.7672)
# accuracy_score: 0.791970802919708
# save the best model
# save the best model
# best_score: 0.791970802919708
# Epoch: [11][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 1s) Loss: 0.5916(0.5916) Grad: 1.5462
# Epoch: [11][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6872(0.6137) Grad: 2.1883
# EVAL: [0/9] Data 3.075 (3.075) Elapsed 0m 3s (remain 0m 25s) Loss: 1.2053(1.2053)
# EVAL: [8/9] Data 0.000 (0.342) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8571(0.9573)
# Epoch    21: reducing learning rate of group 0 to 4.0000e-04.
# accuracy_score: 0.7427007299270073
# Epoch: [12][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 37s) Loss: 0.6334(0.6334) Grad: 1.5100
# Epoch: [12][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5197(0.5084) Grad: 1.2690
# EVAL: [0/9] Data 3.190 (3.190) Elapsed 0m 3s (remain 0m 26s) Loss: 0.6648(0.6648)
# EVAL: [8/9] Data 0.000 (0.355) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6963(0.6277)
# accuracy_score: 0.843065693430657
# save the best model
# save the best model
# best_score: 0.843065693430657
# Epoch: [13][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 4s) Loss: 0.4598(0.4598) Grad: 0.9749
# Epoch: [13][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4415(0.4333) Grad: 1.1917
# EVAL: [0/9] Data 2.876 (2.876) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5796(0.5796)
# EVAL: [8/9] Data 0.000 (0.347) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6650(0.6246)
# accuracy_score: 0.8394160583941606
# Epoch: [14][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 26s) Loss: 0.3869(0.3869) Grad: 1.1404
# Epoch: [14][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4690(0.4186) Grad: 1.3691
# EVAL: [0/9] Data 2.765 (2.765) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5639(0.5639)
# EVAL: [8/9] Data 0.000 (0.341) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5847(0.5991)
# accuracy_score: 0.8613138686131386
# save the best model
# save the best model
# best_score: 0.8613138686131386
# Epoch: [15][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 47s) Loss: 0.3628(0.3628) Grad: 0.8052
# Epoch: [15][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4509(0.4055) Grad: 1.6246
# EVAL: [0/9] Data 2.814 (2.814) Elapsed 0m 2s (remain 0m 23s) Loss: 0.6955(0.6955)
# EVAL: [8/9] Data 0.000 (0.340) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5837(0.7016)
# accuracy_score: 0.8138686131386861
# Epoch: [16][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 16s) Loss: 0.4165(0.4165) Grad: 1.0792
# Epoch: [16][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4008(0.4002) Grad: 1.0818
# EVAL: [0/9] Data 3.048 (3.048) Elapsed 0m 3s (remain 0m 24s) Loss: 0.6292(0.6292)
# EVAL: [8/9] Data 0.000 (0.339) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6223(0.6104)
# Epoch    31: reducing learning rate of group 0 to 1.6000e-04.
# accuracy_score: 0.8631386861313869
# save the best model
# save the best model
# best_score: 0.8631386861313869
# Epoch: [17][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 6s) Loss: 0.4046(0.4046) Grad: 1.2496
# Epoch: [17][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3794(0.3769) Grad: 0.7298
# EVAL: [0/9] Data 2.972 (2.972) Elapsed 0m 3s (remain 0m 24s) Loss: 0.5410(0.5410)
# EVAL: [8/9] Data 0.000 (0.336) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5540(0.5822)
# accuracy_score: 0.8722627737226277
# save the best model
# save the best model
# best_score: 0.8722627737226277
# Epoch: [18][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 6s) Loss: 0.3636(0.3636) Grad: 0.6842
# Epoch: [18][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3943(0.3653) Grad: 1.4163
# EVAL: [0/9] Data 2.896 (2.896) Elapsed 0m 2s (remain 0m 23s) Loss: 0.6097(0.6097)
# EVAL: [8/9] Data 0.000 (0.335) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6835(0.6182)
# accuracy_score: 0.8576642335766423
# Epoch: [19][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 17s) Loss: 0.3973(0.3973) Grad: 1.4270
# Epoch: [19][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3304(0.3645) Grad: 0.5218
# EVAL: [0/9] Data 2.714 (2.714) Elapsed 0m 2s (remain 0m 22s) Loss: 0.6737(0.6737)
# EVAL: [8/9] Data 0.000 (0.329) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5667(0.6285)
# Epoch    37: reducing learning rate of group 0 to 6.4000e-05.
# accuracy_score: 0.8503649635036497
# Epoch: [20][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 7s) Loss: 0.3295(0.3295) Grad: 0.5985
# Epoch: [20][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3820(0.3529) Grad: 0.8836
# EVAL: [0/9] Data 2.936 (2.936) Elapsed 0m 3s (remain 0m 24s) Loss: 0.5944(0.5944)
# EVAL: [8/9] Data 0.000 (0.326) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5966(0.5906)
# accuracy_score: 0.8722627737226277
# Epoch: [21][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 24s) Loss: 0.3936(0.3936) Grad: 1.0162
# Epoch: [21][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3447(0.3400) Grad: 0.7030
# EVAL: [0/9] Data 2.761 (2.761) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5984(0.5984)
# EVAL: [8/9] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5767(0.5928)
# Epoch    41: reducing learning rate of group 0 to 2.5600e-05.
# accuracy_score: 0.8722627737226277
# Epoch: [22][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 23s) Loss: 0.3366(0.3366) Grad: 0.8771
# Epoch: [22][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3479(0.3411) Grad: 0.8690
# EVAL: [0/9] Data 3.120 (3.120) Elapsed 0m 3s (remain 0m 25s) Loss: 0.5889(0.5889)
# EVAL: [8/9] Data 0.000 (0.347) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5791(0.5982)
# accuracy_score: 0.864963503649635
# Epoch: [23][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 58s) Loss: 0.3228(0.3228) Grad: 0.6566
# Epoch: [23][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3666(0.3342) Grad: 0.8970
# EVAL: [0/9] Data 3.053 (3.053) Elapsed 0m 3s (remain 0m 25s) Loss: 0.5795(0.5795)
# EVAL: [8/9] Data 0.000 (0.339) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5885(0.5813)
# accuracy_score: 0.8722627737226277
# Epoch: [24][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 29s) Loss: 0.3390(0.3390) Grad: 0.7408
# Epoch: [24][32/33] Data 0.000 (0.000) Elapsed 0m 17s (remain 0m 0s) Loss: 0.3132(0.3414) Grad: 0.4609
# EVAL: [0/9] Data 2.892 (2.892) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5715(0.5715)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5910(0.5834)
# accuracy_score: 0.8722627737226277
# Epoch: [25][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 2m 57s) Loss: 0.3251(0.3251) Grad: 0.5963
# Epoch: [25][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3067(0.3347) Grad: 0.2360
# EVAL: [0/9] Data 2.904 (2.904) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5829(0.5829)
# EVAL: [8/9] Data 0.000 (0.323) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5710(0.5913)
# Epoch    49: reducing learning rate of group 0 to 1.0240e-05.
# accuracy_score: 0.8686131386861314
# Epoch: [26][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 5s) Loss: 0.3413(0.3413) Grad: 0.6911
# Epoch: [26][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3386(0.3348) Grad: 0.5438
# EVAL: [0/9] Data 3.159 (3.159) Elapsed 0m 3s (remain 0m 25s) Loss: 0.6079(0.6079)
# EVAL: [8/9] Data 0.000 (0.351) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5841(0.5942)
# accuracy_score: 0.8795620437956204
# save the best model
# save the best model
# best_score: 0.8795620437956204
# Epoch: [27][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 43s) Loss: 0.3493(0.3493) Grad: 0.8301
# Epoch: [27][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3418(0.3351) Grad: 0.6931
# EVAL: [0/9] Data 3.069 (3.069) Elapsed 0m 3s (remain 0m 25s) Loss: 0.5905(0.5905)
# EVAL: [8/9] Data 0.000 (0.341) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5752(0.5907)
# Epoch    53: reducing learning rate of group 0 to 4.0960e-06.
# accuracy_score: 0.8759124087591241
# Epoch: [28][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 27s) Loss: 0.3855(0.3855) Grad: 1.0500
# Epoch: [28][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3163(0.3418) Grad: 0.4125
# EVAL: [0/9] Data 2.710 (2.710) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5948(0.5948)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5986(0.5915)
# accuracy_score: 0.8759124087591241
# Epoch: [29][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 27s) Loss: 0.3101(0.3101) Grad: 0.3036
# Epoch: [29][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3365(0.3307) Grad: 0.6658
# EVAL: [0/9] Data 2.860 (2.860) Elapsed 0m 2s (remain 0m 23s) Loss: 0.5893(0.5893)
# EVAL: [8/9] Data 0.000 (0.318) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5860(0.5862)
# Epoch    57: reducing learning rate of group 0 to 1.6384e-06.
# accuracy_score: 0.8759124087591241
# Epoch: [30][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 15s) Loss: 0.3134(0.3134) Grad: 0.4161
# Epoch: [30][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3334(0.3326) Grad: 0.7667
# EVAL: [0/9] Data 2.671 (2.671) Elapsed 0m 2s (remain 0m 21s) Loss: 0.5969(0.5969)
# EVAL: [8/9] Data 0.000 (0.323) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6081(0.5868)
# accuracy_score: 0.8759124087591241
# ======= 3 fold=========
# Epoch: [1][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 25s) Loss: 1.9169(1.9169) Grad: 0.3959
# Epoch: [1][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.1151(1.3449) Grad: 1.8743
# EVAL: [0/9] Data 2.890 (2.890) Elapsed 0m 2s (remain 0m 23s) Loss: 0.7631(0.7631)
# EVAL: [8/9] Data 0.000 (0.333) Elapsed 0m 3s (remain 0m 0s) Loss: 1.2119(1.1367)
# accuracy_score: 0.6116322701688556
# save the best model
# save the best model
# best_score: 0.6116322701688556
# Epoch: [2][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 0s) Loss: 0.9359(0.9359) Grad: 0.8821
# Epoch: [2][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.1436(1.0245) Grad: 1.9304
# EVAL: [0/9] Data 2.967 (2.967) Elapsed 0m 3s (remain 0m 24s) Loss: 0.9365(0.9365)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0249(1.1753)
# accuracy_score: 0.5572232645403377
# Epoch: [3][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 33s) Loss: 0.9652(0.9652) Grad: 1.3630
# Epoch: [3][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8519(0.9261) Grad: 1.2701
# EVAL: [0/9] Data 2.713 (2.713) Elapsed 0m 2s (remain 0m 22s) Loss: 0.6455(0.6455)
# EVAL: [8/9] Data 0.000 (0.336) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0125(1.0335)
# accuracy_score: 0.649155722326454
# save the best model
# save the best model
# best_score: 0.649155722326454
# Epoch: [4][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 16s) Loss: 0.7151(0.7151) Grad: 1.4865
# Epoch: [4][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7102(0.8551) Grad: 1.1646
# EVAL: [0/9] Data 2.764 (2.764) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5704(0.5704)
# EVAL: [8/9] Data 0.000 (0.312) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1144(0.9222)
# accuracy_score: 0.7073170731707317
# save the best model
# save the best model
# best_score: 0.7073170731707317
# Epoch: [5][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 19s) Loss: 0.7013(0.7013) Grad: 1.4238
# Epoch: [5][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8181(0.7974) Grad: 2.6918
# EVAL: [0/9] Data 2.739 (2.739) Elapsed 0m 2s (remain 0m 22s) Loss: 0.6608(0.6608)
# EVAL: [8/9] Data 0.000 (0.332) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0555(1.0255)
# accuracy_score: 0.6660412757973734
# Epoch: [6][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 30s) Loss: 0.6887(0.6887) Grad: 1.6956
# Epoch: [6][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7280(0.7484) Grad: 1.5846
# EVAL: [0/9] Data 2.685 (2.685) Elapsed 0m 2s (remain 0m 22s) Loss: 0.7128(0.7128)
# EVAL: [8/9] Data 0.000 (0.325) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9329(0.8918)
# accuracy_score: 0.7035647279549718
# Epoch: [7][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 29s) Loss: 0.6398(0.6398) Grad: 1.0807
# Epoch: [7][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8209(0.6872) Grad: 1.6274
# EVAL: [0/9] Data 2.945 (2.945) Elapsed 0m 3s (remain 0m 24s) Loss: 0.6506(0.6506)
# EVAL: [8/9] Data 0.000 (0.327) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8334(0.9515)
# accuracy_score: 0.701688555347092
# Epoch: [8][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 39s) Loss: 0.6001(0.6001) Grad: 1.6672
# Epoch: [8][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6722(0.6733) Grad: 1.4285
# EVAL: [0/9] Data 2.700 (2.700) Elapsed 0m 2s (remain 0m 22s) Loss: 0.5362(0.5362)
# EVAL: [8/9] Data 0.000 (0.333) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7939(0.8505)
# accuracy_score: 0.7448405253283302
# save the best model
# save the best model
# best_score: 0.7448405253283302
# Epoch: [9][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 9s) Loss: 0.7129(0.7129) Grad: 2.0184
# Epoch: [9][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6186(0.6145) Grad: 1.8464
# EVAL: [0/9] Data 2.820 (2.820) Elapsed 0m 2s (remain 0m 23s) Loss: 1.0156(1.0156)
# EVAL: [8/9] Data 0.000 (0.313) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7991(1.1525)
# accuracy_score: 0.6303939962476548
# Epoch: [10][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 38s) Loss: 0.6351(0.6351) Grad: 1.5904
# Epoch: [10][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6270(0.6112) Grad: 1.8371
# EVAL: [0/9] Data 2.708 (2.708) Elapsed 0m 2s (remain 0m 22s) Loss: 0.8034(0.8034)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 1.5327(0.9278)
# Epoch    19: reducing learning rate of group 0 to 4.0000e-04.
# accuracy_score: 0.7429643527204502
# Epoch: [11][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 32s) Loss: 0.6312(0.6312) Grad: 1.6699
# Epoch: [11][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5778(0.5179) Grad: 2.0499
# EVAL: [0/9] Data 2.769 (2.769) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4630(0.4630)
# EVAL: [8/9] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8564(0.6902)
# accuracy_score: 0.8161350844277674
# save the best model
# save the best model
# best_score: 0.8161350844277674
# Epoch: [12][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 8s) Loss: 0.4613(0.4613) Grad: 1.3579
# Epoch: [12][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4622(0.4532) Grad: 0.9589
# EVAL: [0/9] Data 2.816 (2.816) Elapsed 0m 2s (remain 0m 23s) Loss: 0.4028(0.4028)
# EVAL: [8/9] Data 0.000 (0.313) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7541(0.6249)
# accuracy_score: 0.8311444652908068
# save the best model
# save the best model
# best_score: 0.8311444652908068
# Epoch: [13][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 25s) Loss: 0.3817(0.3817) Grad: 0.6832
# Epoch: [13][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4167(0.4370) Grad: 1.0895
# EVAL: [0/9] Data 2.948 (2.948) Elapsed 0m 3s (remain 0m 24s) Loss: 0.3847(0.3847)
# EVAL: [8/9] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7314(0.6050)
# accuracy_score: 0.8367729831144465
# save the best model
# save the best model
# best_score: 0.8367729831144465
# Epoch: [14][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 29s) Loss: 0.4127(0.4127) Grad: 1.0165
# Epoch: [14][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4856(0.4263) Grad: 1.3612
# EVAL: [0/9] Data 2.868 (2.868) Elapsed 0m 2s (remain 0m 23s) Loss: 0.3917(0.3917)
# EVAL: [8/9] Data 0.000 (0.332) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5251(0.6008)
# accuracy_score: 0.8536585365853658
# save the best model
# save the best model
# best_score: 0.8536585365853658
# Epoch: [15][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 2m 59s) Loss: 0.4070(0.4070) Grad: 1.2962
# Epoch: [15][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3552(0.4086) Grad: 1.0796
# EVAL: [0/9] Data 3.130 (3.130) Elapsed 0m 3s (remain 0m 25s) Loss: 0.4862(0.4862)
# EVAL: [8/9] Data 0.000 (0.348) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5654(0.6449)
# accuracy_score: 0.8367729831144465
# Epoch: [16][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 8s) Loss: 0.3923(0.3923) Grad: 0.9836
# Epoch: [16][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4408(0.4136) Grad: 1.1093
# EVAL: [0/9] Data 2.745 (2.745) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4317(0.4317)
# EVAL: [8/9] Data 0.000 (0.317) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5737(0.6454)
# Epoch    31: reducing learning rate of group 0 to 1.6000e-04.
# accuracy_score: 0.8311444652908068
# Epoch: [17][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 50s) Loss: 0.3849(0.3849) Grad: 1.0407
# Epoch: [17][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3507(0.3794) Grad: 0.5804
# EVAL: [0/9] Data 2.552 (2.552) Elapsed 0m 2s (remain 0m 21s) Loss: 0.3761(0.3761)
# EVAL: [8/9] Data 0.000 (0.309) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5345(0.5702)
# accuracy_score: 0.8611632270168855
# save the best model
# save the best model
# best_score: 0.8611632270168855
# Epoch: [18][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 53s) Loss: 0.3669(0.3669) Grad: 1.1126
# Epoch: [18][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3197(0.3697) Grad: 0.4984
# EVAL: [0/9] Data 2.725 (2.725) Elapsed 0m 2s (remain 0m 22s) Loss: 0.4150(0.4150)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5166(0.5622)
# accuracy_score: 0.8686679174484052
# save the best model
# save the best model
# best_score: 0.8686679174484052
# Epoch: [19][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 11s) Loss: 0.3265(0.3265) Grad: 0.4750
# Epoch: [19][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3791(0.3621) Grad: 1.2545
# EVAL: [0/9] Data 2.829 (2.829) Elapsed 0m 2s (remain 0m 23s) Loss: 0.3605(0.3605)
# EVAL: [8/9] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4896(0.5586)
# accuracy_score: 0.8705440900562852
# save the best model
# save the best model
# best_score: 0.8705440900562852
# Epoch: [20][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 35s) Loss: 0.4145(0.4145) Grad: 1.2555
# Epoch: [20][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3128(0.3533) Grad: 0.4507
# EVAL: [0/9] Data 2.809 (2.809) Elapsed 0m 2s (remain 0m 23s) Loss: 0.3414(0.3414)
# EVAL: [8/9] Data 0.000 (0.312) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5128(0.5515)
# accuracy_score: 0.8761726078799249
# save the best model
# save the best model
# best_score: 0.8761726078799249
# Epoch: [21][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 29s) Loss: 0.3337(0.3337) Grad: 1.0326
# Epoch: [21][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3403(0.3402) Grad: 0.8785
# EVAL: [0/9] Data 2.974 (2.974) Elapsed 0m 3s (remain 0m 24s) Loss: 0.3656(0.3656)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5599(0.5616)
# accuracy_score: 0.8724202626641651
# Epoch: [22][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 24s) Loss: 0.3354(0.3354) Grad: 0.5164
# Epoch: [22][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3798(0.3498) Grad: 1.1155
# EVAL: [0/9] Data 2.738 (2.738) Elapsed 0m 2s (remain 0m 22s) Loss: 0.3789(0.3789)
# EVAL: [8/9] Data 0.000 (0.339) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5720(0.5746)
# Epoch    43: reducing learning rate of group 0 to 6.4000e-05.
# accuracy_score: 0.874296435272045
# Epoch: [23][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 46s) Loss: 0.3456(0.3456) Grad: 0.9381
# Epoch: [23][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3073(0.3350) Grad: 0.2692
# EVAL: [0/9] Data 2.642 (2.642) Elapsed 0m 2s (remain 0m 21s) Loss: 0.3664(0.3664)
# EVAL: [8/9] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5080(0.5403)
# accuracy_score: 0.874296435272045
# Epoch: [24][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 35s) Loss: 0.3667(0.3667) Grad: 1.2167
# Epoch: [24][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3122(0.3317) Grad: 0.7275
# EVAL: [0/9] Data 2.753 (2.753) Elapsed 0m 2s (remain 0m 22s) Loss: 0.3503(0.3503)
# EVAL: [8/9] Data 0.000 (0.325) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4760(0.5536)
# accuracy_score: 0.8761726078799249
# Epoch: [25][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 55s) Loss: 0.3380(0.3380) Grad: 0.6481
# Epoch: [25][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3197(0.3322) Grad: 0.5207
# EVAL: [0/9] Data 3.006 (3.006) Elapsed 0m 3s (remain 0m 24s) Loss: 0.3702(0.3702)
# EVAL: [8/9] Data 0.000 (0.334) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4773(0.5380)
# accuracy_score: 0.8818011257035647
# save the best model
# save the best model
# best_score: 0.8818011257035647
# Epoch: [26][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 22s) Loss: 0.3412(0.3412) Grad: 0.6361
# Epoch: [26][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3213(0.3281) Grad: 0.7276
# EVAL: [0/9] Data 2.726 (2.726) Elapsed 0m 2s (remain 0m 22s) Loss: 0.3518(0.3518)
# EVAL: [8/9] Data 0.000 (0.337) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4816(0.5339)
# accuracy_score: 0.8761726078799249
# Epoch: [27][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 49s) Loss: 0.3100(0.3100) Grad: 0.2748
# Epoch: [27][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3266(0.3314) Grad: 0.5526
# EVAL: [0/9] Data 2.939 (2.939) Elapsed 0m 3s (remain 0m 24s) Loss: 0.3526(0.3526)
# EVAL: [8/9] Data 0.000 (0.327) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4691(0.5435)
# accuracy_score: 0.8761726078799249
# Epoch: [28][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 39s) Loss: 0.3285(0.3285) Grad: 0.6283
# Epoch: [28][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3106(0.3217) Grad: 0.3914
# EVAL: [0/9] Data 3.133 (3.133) Elapsed 0m 3s (remain 0m 25s) Loss: 0.3513(0.3513)
# EVAL: [8/9] Data 0.000 (0.348) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4837(0.5384)
# Epoch    55: reducing learning rate of group 0 to 2.5600e-05.
# accuracy_score: 0.8780487804878049
# Epoch: [29][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.3353(0.3353) Grad: 0.6822
# Epoch: [29][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3977(0.3278) Grad: 1.1117
# EVAL: [0/9] Data 2.517 (2.517) Elapsed 0m 2s (remain 0m 20s) Loss: 0.3612(0.3612)
# EVAL: [8/9] Data 0.000 (0.295) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4848(0.5417)
# accuracy_score: 0.8761726078799249
# Epoch: [30][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 47s) Loss: 0.3157(0.3157) Grad: 0.7138
# Epoch: [30][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3142(0.3217) Grad: 0.5263
# EVAL: [0/9] Data 2.731 (2.731) Elapsed 0m 2s (remain 0m 22s) Loss: 0.3686(0.3686)
# EVAL: [8/9] Data 0.000 (0.330) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4651(0.5382)
# Epoch    59: reducing learning rate of group 0 to 1.0240e-05.
# accuracy_score: 0.8818011257035647
# ======= 4 fold=========
# Epoch: [1][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 46s) Loss: 1.9530(1.9530) Grad: 0.4874
# Epoch: [1][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.1198(1.3467) Grad: 1.3518
# EVAL: [0/10] Data 3.322 (3.322) Elapsed 0m 3s (remain 0m 30s) Loss: 0.8390(0.8390)
# EVAL: [9/10] Data 0.000 (0.332) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9530(1.1242)
# accuracy_score: 0.6301369863013698
# save the best model
# save the best model
# best_score: 0.6301369863013698
# Epoch: [2][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 29s) Loss: 1.0433(1.0433) Grad: 1.7205
# Epoch: [2][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9389(1.0764) Grad: 1.2497
# EVAL: [0/10] Data 3.187 (3.187) Elapsed 0m 3s (remain 0m 29s) Loss: 0.7358(0.7358)
# EVAL: [9/10] Data 0.000 (0.319) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0843(1.0742)
# accuracy_score: 0.6592465753424658
# save the best model
# save the best model
# best_score: 0.6592465753424658
# Epoch: [3][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 26s) Loss: 0.8546(0.8546) Grad: 1.2234
# Epoch: [3][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9978(0.9802) Grad: 1.3352
# EVAL: [0/10] Data 3.148 (3.148) Elapsed 0m 3s (remain 0m 29s) Loss: 0.6272(0.6272)
# EVAL: [9/10] Data 0.000 (0.315) Elapsed 0m 3s (remain 0m 0s) Loss: 1.2684(1.0031)
# accuracy_score: 0.7311643835616438
# save the best model
# save the best model
# best_score: 0.7311643835616438
# Epoch: [4][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 24s) Loss: 0.8866(0.8866) Grad: 1.5254
# Epoch: [4][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7844(0.8886) Grad: 1.1945
# EVAL: [0/10] Data 3.044 (3.044) Elapsed 0m 3s (remain 0m 28s) Loss: 0.7938(0.7938)
# EVAL: [9/10] Data 0.000 (0.309) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9306(0.9908)
# accuracy_score: 0.6866438356164384
# Epoch: [5][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 7s) Loss: 0.6838(0.6838) Grad: 1.3412
# Epoch: [5][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8401(0.8176) Grad: 2.1978
# EVAL: [0/10] Data 3.396 (3.396) Elapsed 0m 3s (remain 0m 31s) Loss: 0.6467(0.6467)
# EVAL: [9/10] Data 0.000 (0.340) Elapsed 0m 4s (remain 0m 0s) Loss: 0.8664(0.9286)
# accuracy_score: 0.7311643835616438
# Epoch: [6][0/33] Data 0.000 (0.000) Elapsed 0m 9s (remain 4m 49s) Loss: 0.6760(0.6760) Grad: 1.5234
# Epoch: [6][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7872(0.8032) Grad: 1.1503
# EVAL: [0/10] Data 3.240 (3.240) Elapsed 0m 3s (remain 0m 29s) Loss: 0.6472(0.6472)
# EVAL: [9/10] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7076(0.8090)
# accuracy_score: 0.7773972602739726
# save the best model
# save the best model
# best_score: 0.7773972602739726
# Epoch: [7][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 25s) Loss: 0.9355(0.9355) Grad: 1.7634
# Epoch: [7][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7979(0.7695) Grad: 1.5528
# EVAL: [0/10] Data 2.919 (2.919) Elapsed 0m 2s (remain 0m 26s) Loss: 0.6406(0.6406)
# EVAL: [9/10] Data 0.000 (0.314) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8736(0.8539)
# accuracy_score: 0.7482876712328768
# Epoch: [8][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 26s) Loss: 0.7067(0.7067) Grad: 1.6078
# Epoch: [8][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6759(0.6844) Grad: 1.4635
# EVAL: [0/10] Data 3.138 (3.138) Elapsed 0m 3s (remain 0m 28s) Loss: 0.6853(0.6853)
# EVAL: [9/10] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5642(0.7632)
# accuracy_score: 0.785958904109589
# save the best model
# save the best model
# best_score: 0.785958904109589
# Epoch: [9][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 21s) Loss: 0.7697(0.7697) Grad: 2.3394
# Epoch: [9][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7881(0.6447) Grad: 2.3446
# EVAL: [0/10] Data 2.887 (2.887) Elapsed 0m 2s (remain 0m 26s) Loss: 0.5726(0.5726)
# EVAL: [9/10] Data 0.000 (0.305) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5153(0.7006)
# accuracy_score: 0.8133561643835616
# save the best model
# save the best model
# best_score: 0.8133561643835616
# Epoch: [10][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.6547(0.6547) Grad: 2.5188
# Epoch: [10][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5725(0.5998) Grad: 1.3421
# EVAL: [0/10] Data 3.374 (3.374) Elapsed 0m 3s (remain 0m 31s) Loss: 0.6683(0.6683)
# EVAL: [9/10] Data 0.000 (0.337) Elapsed 0m 4s (remain 0m 0s) Loss: 0.6223(0.7501)
# accuracy_score: 0.7893835616438356
# Epoch: [11][0/33] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 45s) Loss: 0.6881(0.6881) Grad: 1.7211
# Epoch: [11][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4991(0.6147) Grad: 1.2405
# EVAL: [0/10] Data 3.290 (3.290) Elapsed 0m 3s (remain 0m 30s) Loss: 0.4597(0.4597)
# EVAL: [9/10] Data 0.000 (0.335) Elapsed 0m 4s (remain 0m 0s) Loss: 0.8011(0.6974)
# accuracy_score: 0.8287671232876712
# save the best model
# save the best model
# best_score: 0.8287671232876712
# Epoch: [12][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 13s) Loss: 0.4824(0.4824) Grad: 1.3474
# Epoch: [12][32/33] Data 0.000 (0.000) Elapsed 0m 17s (remain 0m 0s) Loss: 0.6285(0.5485) Grad: 1.8326
# EVAL: [0/10] Data 2.974 (2.974) Elapsed 0m 3s (remain 0m 27s) Loss: 0.7328(0.7328)
# EVAL: [9/10] Data 0.000 (0.320) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6487(0.7293)
# accuracy_score: 0.8013698630136986
# Epoch: [13][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 33s) Loss: 0.5330(0.5330) Grad: 1.4069
# Epoch: [13][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6065(0.5407) Grad: 1.7405
# EVAL: [0/10] Data 2.919 (2.919) Elapsed 0m 2s (remain 0m 26s) Loss: 0.8759(0.8759)
# EVAL: [9/10] Data 0.000 (0.323) Elapsed 0m 3s (remain 0m 0s) Loss: 1.0509(0.8610)
# Epoch    25: reducing learning rate of group 0 to 4.0000e-04.
# accuracy_score: 0.7636986301369864
# Epoch: [14][0/33] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 10s) Loss: 0.7223(0.7223) Grad: 2.2733
# Epoch: [14][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4260(0.4776) Grad: 1.3148
# EVAL: [0/10] Data 2.962 (2.962) Elapsed 0m 3s (remain 0m 27s) Loss: 0.5464(0.5464)
# EVAL: [9/10] Data 0.000 (0.319) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6018(0.5860)
# accuracy_score: 0.8613013698630136
# save the best model
# save the best model
# best_score: 0.8613013698630136
# Epoch: [15][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 35s) Loss: 0.4701(0.4701) Grad: 1.3160
# Epoch: [15][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3764(0.4102) Grad: 0.6523
# EVAL: [0/10] Data 3.060 (3.060) Elapsed 0m 3s (remain 0m 28s) Loss: 0.5501(0.5501)
# EVAL: [9/10] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6066(0.6214)
# accuracy_score: 0.8561643835616438
# Epoch: [16][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 25s) Loss: 0.3401(0.3401) Grad: 0.5968
# Epoch: [16][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4798(0.4124) Grad: 1.3163
# EVAL: [0/10] Data 3.211 (3.211) Elapsed 0m 3s (remain 0m 29s) Loss: 0.5907(0.5907)
# EVAL: [9/10] Data 0.000 (0.326) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5404(0.6013)
# Epoch    31: reducing learning rate of group 0 to 1.6000e-04.
# accuracy_score: 0.8561643835616438
# Epoch: [17][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 45s) Loss: 0.3720(0.3720) Grad: 0.8431
# ...
# save the best model
# save the best model
# best_score: 0.9092465753424658
# Epoch: [25][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.3341(0.3341) Grad: 0.4376
# Epoch: [25][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3719(0.3492) Grad: 0.8735
# EVAL: [0/10] Data 3.067 (3.067) Elapsed 0m 3s (remain 0m 28s) Loss: 0.5452(0.5452)
# EVAL: [9/10] Data 0.000 (0.338) Elapsed 0m 4s (remain 0m 0s) Loss: 0.5156(0.5240)
# accuracy_score: 0.8955479452054794
# Epoch: [26][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 27s) Loss: 0.3404(0.3404) Grad: 0.7544
# Epoch: [26][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3692(0.3437) Grad: 0.8613
# EVAL: [0/10] Data 2.923 (2.923) Elapsed 0m 2s (remain 0m 26s) Loss: 0.5475(0.5475)
# EVAL: [9/10] Data 0.000 (0.293) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4793(0.5251)
# accuracy_score: 0.9023972602739726
# Epoch: [27][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 44s) Loss: 0.3073(0.3073) Grad: 0.3299
# Epoch: [27][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3113(0.3386) Grad: 0.3003
# EVAL: [0/10] Data 3.043 (3.043) Elapsed 0m 3s (remain 0m 28s) Loss: 0.5412(0.5412)
# EVAL: [9/10] Data 0.000 (0.337) Elapsed 0m 4s (remain 0m 0s) Loss: 0.5267(0.5210)
# accuracy_score: 0.9058219178082192
# Epoch: [28][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 16s) Loss: 0.3016(0.3016) Grad: 0.2098
# Epoch: [28][32/33] Data 0.000 (0.000) Elapsed 0m 17s (remain 0m 0s) Loss: 0.3060(0.3298) Grad: 0.5128
# EVAL: [0/10] Data 3.130 (3.130) Elapsed 0m 3s (remain 0m 28s) Loss: 0.4881(0.4881)
# EVAL: [9/10] Data 0.000 (0.317) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4613(0.5312)
# accuracy_score: 0.8955479452054794
# Epoch: [29][0/33] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 40s) Loss: 0.3167(0.3167) Grad: 0.3678
# Epoch: [29][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3018(0.3316) Grad: 0.3411
# EVAL: [0/10] Data 3.235 (3.235) Elapsed 0m 3s (remain 0m 29s) Loss: 0.4564(0.4564)
# EVAL: [9/10] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.5600(0.5442)
# Epoch    57: reducing learning rate of group 0 to 6.4000e-05.
# accuracy_score: 0.8972602739726028
# Epoch: [30][0/33] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 43s) Loss: 0.2971(0.2971) Grad: 0.2347
# Epoch: [30][32/33] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3296(0.3292) Grad: 0.8554
# EVAL: [0/10] Data 2.986 (2.986) Elapsed 0m 3s (remain 0m 27s) Loss: 0.4803(0.4803)
# EVAL: [9/10] Data 0.000 (0.303) Elapsed 0m 3s (remain 0m 0s) Loss: 0.4633(0.5374)
# accuracy_score: 0.8938356164383562
# ======= 5 fold=========
# Epoch: [1][0/34] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 11s) Loss: 1.9729(1.9729) Grad: 0.4076
# Epoch: [1][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 1.0977(1.3138) Grad: 1.5850
# EVAL: [0/8] Data 2.409 (2.409) Elapsed 0m 2s (remain 0m 17s) Loss: 0.8631(0.8631)
# EVAL: [7/8] Data 0.000 (0.322) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8151(1.0953)
# accuracy_score: 0.6521739130434783
# save the best model
# save the best model
# best_score: 0.6521739130434783
# Epoch: [2][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 52s) Loss: 1.0236(1.0236) Grad: 1.3233
# Epoch: [2][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9837(1.0582) Grad: 1.4273
# EVAL: [0/8] Data 2.514 (2.514) Elapsed 0m 2s (remain 0m 18s) Loss: 0.7953(0.7953)
# EVAL: [7/8] Data 0.000 (0.314) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1846(1.0651)
# accuracy_score: 0.6687370600414079
# save the best model
# save the best model
# best_score: 0.6687370600414079
# Epoch: [3][0/34] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 41s) Loss: 1.0678(1.0678) Grad: 2.3916
# Epoch: [3][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9281(0.9366) Grad: 2.0543
# EVAL: [0/8] Data 2.932 (2.932) Elapsed 0m 3s (remain 0m 21s) Loss: 0.7058(0.7058)
# EVAL: [7/8] Data 0.000 (0.367) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9374(0.9689)
# accuracy_score: 0.6853002070393375
# save the best model
# save the best model
# best_score: 0.6853002070393375
# Epoch: [4][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 4s) Loss: 0.8140(0.8140) Grad: 1.6745
# Epoch: [4][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8065(0.8392) Grad: 1.2639
# EVAL: [0/8] Data 2.519 (2.519) Elapsed 0m 2s (remain 0m 18s) Loss: 0.7608(0.7608)
# EVAL: [7/8] Data 0.000 (0.337) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9922(0.8704)
# accuracy_score: 0.7308488612836439
# save the best model
# save the best model
# best_score: 0.7308488612836439
# Epoch: [5][0/34] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 48s) Loss: 0.9474(0.9474) Grad: 2.0275
# Epoch: [5][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8107(0.8088) Grad: 2.2404
# EVAL: [0/8] Data 2.842 (2.842) Elapsed 0m 2s (remain 0m 20s) Loss: 0.6501(0.6501)
# EVAL: [7/8] Data 0.000 (0.355) Elapsed 0m 3s (remain 0m 0s) Loss: 1.1690(0.9483)
# accuracy_score: 0.7184265010351967
# Epoch: [6][0/34] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 9s) Loss: 0.8468(0.8468) Grad: 2.1911
# Epoch: [6][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.8205(0.7397) Grad: 1.5719
# EVAL: [0/8] Data 2.520 (2.520) Elapsed 0m 2s (remain 0m 18s) Loss: 0.6247(0.6247)
# EVAL: [7/8] Data 0.000 (0.354) Elapsed 0m 3s (remain 0m 0s) Loss: 1.2384(0.8364)
# accuracy_score: 0.772256728778468
# save the best model
# save the best model
# best_score: 0.772256728778468
# Epoch: [7][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 34s) Loss: 0.5991(0.5991) Grad: 1.2385
# Epoch: [7][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.9076(0.7716) Grad: 2.0543
# EVAL: [0/8] Data 2.785 (2.785) Elapsed 0m 2s (remain 0m 20s) Loss: 0.6862(0.6862)
# EVAL: [7/8] Data 0.000 (0.348) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8945(0.8204)
# accuracy_score: 0.7453416149068323
# Epoch: [8][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 39s) Loss: 0.6676(0.6676) Grad: 1.1113
# Epoch: [8][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7035(0.6667) Grad: 2.0387
# EVAL: [0/8] Data 2.675 (2.675) Elapsed 0m 2s (remain 0m 19s) Loss: 0.6047(0.6047)
# EVAL: [7/8] Data 0.000 (0.335) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8447(0.7652)
# accuracy_score: 0.7950310559006211
# save the best model
# save the best model
# best_score: 0.7950310559006211
# Epoch: [9][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 18s) Loss: 0.5390(0.5390) Grad: 1.6408
# Epoch: [9][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5986(0.6099) Grad: 1.8704
# EVAL: [0/8] Data 2.742 (2.742) Elapsed 0m 2s (remain 0m 19s) Loss: 0.7407(0.7407)
# EVAL: [7/8] Data 0.000 (0.349) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9053(0.7312)
# accuracy_score: 0.8115942028985508
# save the best model
# save the best model
# best_score: 0.8115942028985508
# Epoch: [10][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 33s) Loss: 0.5082(0.5082) Grad: 1.1904
# Epoch: [10][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.7864(0.6084) Grad: 1.8610
# EVAL: [0/8] Data 2.438 (2.438) Elapsed 0m 2s (remain 0m 17s) Loss: 0.6822(0.6822)
# EVAL: [7/8] Data 0.000 (0.335) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6621(0.7486)
# accuracy_score: 0.8074534161490683
# Epoch: [11][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 39s) Loss: 0.5296(0.5296) Grad: 1.2117
# Epoch: [11][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5511(0.5841) Grad: 1.4514
# EVAL: [0/8] Data 2.704 (2.704) Elapsed 0m 2s (remain 0m 19s) Loss: 0.6688(0.6688)
# EVAL: [7/8] Data 0.000 (0.353) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6749(0.6597)
# accuracy_score: 0.8178053830227743
# save the best model
# save the best model
# best_score: 0.8178053830227743
# Epoch: [12][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 45s) Loss: 0.4936(0.4936) Grad: 1.3055
# Epoch: [12][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4192(0.5430) Grad: 0.9628
# EVAL: [0/8] Data 2.770 (2.770) Elapsed 0m 2s (remain 0m 19s) Loss: 0.5989(0.5989)
# EVAL: [7/8] Data 0.000 (0.346) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9001(0.7070)
# accuracy_score: 0.8095238095238095
# Epoch: [13][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 49s) Loss: 0.4484(0.4484) Grad: 1.0526
# Epoch: [13][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.6495(0.5293) Grad: 2.0431
# EVAL: [0/8] Data 2.581 (2.581) Elapsed 0m 2s (remain 0m 18s) Loss: 0.7230(0.7230)
# EVAL: [7/8] Data 0.000 (0.328) Elapsed 0m 3s (remain 0m 0s) Loss: 0.9211(0.7272)
# Epoch    25: reducing learning rate of group 0 to 4.0000e-04.
# accuracy_score: 0.8074534161490683
# Epoch: [14][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 19s) Loss: 0.4099(0.4099) Grad: 0.9191
# Epoch: [14][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.5080(0.4644) Grad: 1.4721
# EVAL: [0/8] Data 2.605 (2.605) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4993(0.4993)
# EVAL: [7/8] Data 0.000 (0.340) Elapsed 0m 3s (remain 0m 0s) Loss: 0.8308(0.5663)
# accuracy_score: 0.8592132505175983
# save the best model
# save the best model
# best_score: 0.8592132505175983
# Epoch: [15][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 31s) Loss: 0.4561(0.4561) Grad: 1.2458
# Epoch: [15][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4231(0.4225) Grad: 1.4304
# EVAL: [0/8] Data 2.626 (2.626) Elapsed 0m 2s (remain 0m 18s) Loss: 0.5303(0.5303)
# EVAL: [7/8] Data 0.000 (0.343) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6747(0.5555)
# accuracy_score: 0.8695652173913043
# save the best model
# save the best model
# best_score: 0.8695652173913043
# Epoch: [16][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 51s) Loss: 0.4322(0.4322) Grad: 0.9355
# Epoch: [16][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.4826(0.4041) Grad: 1.8431
# EVAL: [0/8] Data 2.616 (2.616) Elapsed 0m 2s (remain 0m 18s) Loss: 0.6604(0.6604)
# EVAL: [7/8] Data 0.000 (0.333) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6814(0.5998)
# accuracy_score: 0.8530020703933747
# Epoch: [17][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 54s) Loss: 0.4450(0.4450) Grad: 2.2746
# Epoch: [17][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3762(0.4039) Grad: 0.7574
# EVAL: [0/8] Data 2.631 (2.631) Elapsed 0m 2s (remain 0m 18s) Loss: 0.5473(0.5473)
# EVAL: [7/8] Data 0.000 (0.343) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6992(0.5438)
# accuracy_score: 0.8757763975155279
# save the best model
# save the best model
# best_score: 0.8757763975155279
# Epoch: [18][0/34] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 5s) Loss: 0.3512(0.3512) Grad: 0.5303
# Epoch: [18][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3894(0.3795) Grad: 1.0156
# EVAL: [0/8] Data 2.697 (2.697) Elapsed 0m 2s (remain 0m 19s) Loss: 0.4458(0.4458)
# EVAL: [7/8] Data 0.000 (0.337) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7428(0.5501)
# accuracy_score: 0.8757763975155279
# Epoch: [19][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 3s) Loss: 0.3276(0.3276) Grad: 0.2601
# Epoch: [19][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3456(0.3857) Grad: 0.9173
# EVAL: [0/8] Data 2.656 (2.656) Elapsed 0m 2s (remain 0m 19s) Loss: 0.4536(0.4536)
# EVAL: [7/8] Data 0.000 (0.354) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6787(0.5388)
# accuracy_score: 0.8861283643892339
# save the best model
# save the best model
# best_score: 0.8861283643892339
# Epoch: [20][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 58s) Loss: 0.3721(0.3721) Grad: 0.8763
# Epoch: [20][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3958(0.3746) Grad: 1.0606
# EVAL: [0/8] Data 2.512 (2.512) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4457(0.4457)
# EVAL: [7/8] Data 0.000 (0.321) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6220(0.5250)
# accuracy_score: 0.9026915113871635
# save the best model
# save the best model
# best_score: 0.9026915113871635
# Epoch: [21][0/34] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 31s) Loss: 0.3321(0.3321) Grad: 0.4296
# Epoch: [21][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3686(0.3605) Grad: 1.1197
# EVAL: [0/8] Data 2.547 (2.547) Elapsed 0m 2s (remain 0m 18s) Loss: 0.5296(0.5296)
# EVAL: [7/8] Data 0.000 (0.324) Elapsed 0m 3s (remain 0m 0s) Loss: 0.7370(0.5583)
# accuracy_score: 0.8716356107660456
# Epoch: [22][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 38s) Loss: 0.3337(0.3337) Grad: 0.5754
# Epoch: [22][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3786(0.3664) Grad: 1.2495
# EVAL: [0/8] Data 2.553 (2.553) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4748(0.4748)
# EVAL: [7/8] Data 0.000 (0.325) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6819(0.5452)
# Epoch    43: reducing learning rate of group 0 to 1.6000e-04.
# accuracy_score: 0.8674948240165632
# Epoch: [23][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 55s) Loss: 0.3348(0.3348) Grad: 0.5523
# Epoch: [23][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3138(0.3515) Grad: 0.4056
# EVAL: [0/8] Data 2.477 (2.477) Elapsed 0m 2s (remain 0m 17s) Loss: 0.4533(0.4533)
# EVAL: [7/8] Data 0.000 (0.339) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6515(0.5290)
# accuracy_score: 0.8861283643892339
# Epoch: [24][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 46s) Loss: 0.3822(0.3822) Grad: 1.2145
# Epoch: [24][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3239(0.3455) Grad: 0.4866
# EVAL: [0/8] Data 2.550 (2.550) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4786(0.4786)
# EVAL: [7/8] Data 0.000 (0.332) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6568(0.5285)
# Epoch    47: reducing learning rate of group 0 to 6.4000e-05.
# accuracy_score: 0.8861283643892339
# Epoch: [25][0/34] Data 0.000 (0.000) Elapsed 0m 8s (remain 4m 45s) Loss: 0.3056(0.3056) Grad: 0.2116
# Epoch: [25][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3122(0.3310) Grad: 0.5844
# EVAL: [0/8] Data 2.816 (2.816) Elapsed 0m 2s (remain 0m 20s) Loss: 0.4714(0.4714)
# EVAL: [7/8] Data 0.000 (0.352) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6376(0.5173)
# accuracy_score: 0.8902691511387164
# Epoch: [26][0/34] Data 0.000 (0.000) Elapsed 0m 5s (remain 3m 13s) Loss: 0.3069(0.3069) Grad: 0.2317
# Epoch: [26][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3148(0.3302) Grad: 0.2226
# EVAL: [0/8] Data 2.833 (2.833) Elapsed 0m 2s (remain 0m 20s) Loss: 0.4625(0.4625)
# EVAL: [7/8] Data 0.000 (0.354) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6030(0.5158)
# accuracy_score: 0.9047619047619048
# save the best model
# save the best model
# best_score: 0.9047619047619048
# Epoch: [27][0/34] Data 0.000 (0.000) Elapsed 0m 6s (remain 3m 33s) Loss: 0.3136(0.3136) Grad: 0.6697
# Epoch: [27][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3253(0.3214) Grad: 0.3993
# EVAL: [0/8] Data 2.451 (2.451) Elapsed 0m 2s (remain 0m 17s) Loss: 0.4489(0.4489)
# EVAL: [7/8] Data 0.000 (0.311) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6163(0.5116)
# accuracy_score: 0.8944099378881988
# Epoch: [28][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 10s) Loss: 0.2978(0.2978) Grad: 0.1696
# Epoch: [28][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3211(0.3253) Grad: 0.6910
# EVAL: [0/8] Data 2.565 (2.565) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4577(0.4577)
# EVAL: [7/8] Data 0.000 (0.341) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6389(0.5173)
# accuracy_score: 0.8902691511387164
# Epoch: [29][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 3m 57s) Loss: 0.3307(0.3307) Grad: 0.4402
# Epoch: [29][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.3141(0.3181) Grad: 0.3377
# EVAL: [0/8] Data 2.523 (2.523) Elapsed 0m 2s (remain 0m 18s) Loss: 0.4381(0.4381)
# EVAL: [7/8] Data 0.000 (0.338) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6126(0.5113)
# accuracy_score: 0.8985507246376812
# Epoch: [30][0/34] Data 0.000 (0.000) Elapsed 0m 7s (remain 4m 20s) Loss: 0.3199(0.3199) Grad: 0.6117
# Epoch: [30][33/34] Data 0.000 (0.000) Elapsed 0m 18s (remain 0m 0s) Loss: 0.2996(0.3177) Grad: 0.2193
# EVAL: [0/8] Data 2.839 (2.839) Elapsed 0m 2s (remain 0m 20s) Loss: 0.4379(0.4379)
# EVAL: [7/8] Data 0.000 (0.355) Elapsed 0m 3s (remain 0m 0s) Loss: 0.6098(0.5093)
# accuracy_score: 0.9026915113871635

# %%
from sklearn.metrics import classification_report
df=pd.DataFrame(pd.read_csv('oof_df.csv',encoding='GBK'))
print(classification_report(df['label'], df['preds']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.83      0.74       151
#            1       0.49      0.70      0.58       122
#            2       0.61      0.45      0.52        66
#            3       0.34      0.12      0.18        92
#            4       0.81      0.88      0.84        33
#            5       0.69      0.54      0.60        54
#            6       0.97      0.82      0.89        39
#
#     accuracy                           0.62       557
#    macro avg       0.65      0.62      0.62       557
# weighted avg       0.60      0.62      0.59       557

# %%
##################################################################
#一下内容是对所有的子图预测概率相加,选取概率最大的作为分类的选项
#################################################################

# %%
df = pd.read_csv('./oof_df.csv')
result_df = pd.read_csv('./rock_label.csv',encoding='GBK')
df.head()
# Out:
#   image_id  label  fold         0         1         2         3         4  \
# 0  1_2.bmp      1     0  0.004318  0.959787  0.004109  0.005047  0.011146
# 1  1_5.bmp      1     0  0.005965  0.952053  0.005230  0.008619  0.012052
# 2  1_8.bmp      1     0  0.004616  0.968674  0.003598  0.006369  0.007163
# 3  2_1.bmp      6     0  0.005773  0.005810  0.007537  0.006670  0.006135
# 4  2_6.bmp      6     0  0.009843  0.009663  0.010891  0.010237  0.010922
#
#           5         6  preds
# 0  0.006536  0.009059      1
# 1  0.006345  0.009736      1
# 2  0.004348  0.005232      1
# 3  0.005930  0.962144      6
# 4  0.008309  0.940135      6

# %%
#增加列
result_df['0'] =  0.0
result_df['1'] =  0.0
result_df['2'] =  0.0
result_df['3'] =  0.0
result_df['4'] =  0.0
result_df['5'] =  0.0
result_df['6'] =  0.0
result_df['preds'] =  None
#result_df['preds'] =  None
result_df

# %%
from sklearn.metrics import classification_report
print(classification_report(df['label'], df['preds']))

# %%
for loc_index in range (result_df.shape[0]):
    #print('star')
    #print(loc_index)
    a = result_df[loc_index:loc_index+1]
    main_name = int(a['样本编号'].values)
    #print(main_name)
    for loc_idx in range(df.shape[0]):    
        b = df[loc_idx:loc_idx+1]#取出行
        image_name = str(b['image_id'].values)
        filename, name_suffix = os.path.splitext(image_name)
        name = filename.split('_')[0]  # '-'前面的文件名
        m_name = int( name.split("'")[1])
        #print(m_name)
        if m_name == main_name:
            a = result_df[loc_index:loc_index+1]
            #print(m_name)
            a['0'] = float(b['0'].values) + float(a['0'].values)
            a['1'] = float(b['1'].values) + float(a['1'].values)
            a['2'] = float(b['2'].values) + float(a['2'].values)
            a['3'] = float(b['3'].values) + float(a['3'].values)
            a['4'] = float(b['4'].values) + float(a['4'].values)
            a['5'] = float(b['5'].values) + float(a['5'].values)
            a['6'] = float(b['6'].values) + float(a['6'].values)
            result_df[loc_index:loc_index+1] = a
            #print(a)

# %%
result_df

# %%
for loc_index in range (result_df.shape[0]):
    a = result_df[loc_index:loc_index+1]#取出列
    list1 = [float(a['0'].values),
         float(a['1'].values),
         float(a['2'].values),
         float(a['3'].values),
         float(a['4'].values),
         float(a['5'].values),
         float(a['6'].values),]
    a['preds'] = list1.index(max(list1))
    result_df[loc_index:loc_index+1] = a

# %%
from sklearn.preprocessing import LabelEncoder
#标签编码
le=LabelEncoder()
le.fit(result_df['样本类别'].values.tolist())
le.classes_
result_df['样本类别']=le.transform(result_df['样本类别'].values.tolist())
result_df.rename(columns={'样本类别':'label'},inplace=True)
result_df

# %%
result_df.to_csv("./result.csv", encoding="GBK",index=False)#save file

# %%
result_df = pd.read_csv('./result.csv',encoding='GBK')
print(classification_report(result_df['label'], result_df['preds']))

# %%
from sklearn.metrics import accuracy_score
print(accuracy_score(result_df['label'], result_df['preds']))
